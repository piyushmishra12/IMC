# %%
import cv2
import numpy as np
gen_seq = cv2.imread('gen_seq.png')

# %%
gen_seq = cv2.resize(gen_seq, dsize=(1500, 1500))

# %%
gen_seq
# Out:
# array([[[136, 143,  40],
#         [119, 145,  71],
#         [ 81, 196, 147],
#         ...,
#         [ 75,  44, 103],
#         [ 90,  27,  69],
#         [ 85,  36,  82]],
#
#        [[ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68],
#         ...,
#         [ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68]],
#
#        [[ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68],
#         ...,
#         [ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68]],
#
#        ...,
#
#        [[ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68],
#         ...,
#         [ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68]],
#
#        [[ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68],
#         ...,
#         [ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68]],
#
#        [[ 84,   1,  68],
#         [ 84,   1,  68],
#         [ 84,   1,  68],
# ...

# %%
from matplotlib import pyplot as plt
plt.imshow(gen_seq, interpolation='nearest')
plt.show()

# %%
plt.imsave('gen_seq_resized.png', gen_seq)

# %%
from PIL import Image
img = Image.open("gen_seq_resized.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x1500 at 0x1255114E0>

# %%
gen_seq.size
# Out:
# 6750000

# %%
gen_exp = cv2.imread('gen_exp.png')

# %%
gen_exp.size
# Out:
# 62400

# %%
gen_exp = cv2.resize(gen_exp, dsize=(1500, 1500))

# %%
gen_exp
# Out:
# array([[[139,  83,  58],
#         [139,  83,  58],
#         [139,  83,  58],
#         ...,
#         [134,  65,  65],
#         [134,  65,  65],
#         [134,  65,  65]],
#
#        [[139,  83,  58],
#         [139,  83,  58],
#         [139,  83,  58],
#         ...,
#         [134,  65,  65],
#         [134,  65,  65],
#         [134,  65,  65]],
#
#        [[139,  83,  58],
#         [139,  83,  58],
#         [139,  83,  58],
#         ...,
#         [134,  65,  65],
#         [134,  65,  65],
#         [134,  65,  65]],
#
#        ...,
#
#        [[142, 122,  40],
#         [142, 122,  40],
#         [142, 122,  40],
#         ...,
#         [124,  45,  70],
#         [124,  45,  70],
#         [124,  45,  70]],
#
#        [[142, 122,  40],
#         [142, 122,  40],
#         [142, 122,  40],
#         ...,
#         [124,  45,  70],
#         [124,  45,  70],
#         [124,  45,  70]],
#
#        [[142, 122,  40],
#         [142, 122,  40],
#         [142, 122,  40],
# ...

# %%
plt.imshow(gen_exp, interpolation='nearest')
plt.show()

# %%
pdb = cv2.imread('pdb_id_dist.png')

# %%
pdb = cv2.resize(pdb, dsize=(1500, 1500))

# %%
plt.imshow(pdb, interpolation='nearest')
plt.show()
